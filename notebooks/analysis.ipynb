# %%
import numpy as np
import pandas as pd


import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('discount_code_data.csv')

# %%
df.shape
# Out:
# (2609194, 69)

# %%
df.columns
# Out:
# Index(['id', 'discount_code', 'applied_count', 'failed', 'failed_reason',
#        'created_at', 'updated_at', 'cart_id', 'checkout_id', 'id.1', 'token',
#        'reason', 'created_at.1', 'updated_at.1', 'subtotal_price',
#        'total_price', 'order_id', 'order_data', 'customer_email',
#        'customer_mobile', 'order_name', 'is_payment_online', 'verified_cart',
#        'final_subtotal_price', 'final_total_price', 'cart_state', 'first_name',
#        'last_name', 'final_discount', 'final_shipping', 'outstation',
#        'email_reciept', 'payment_modal', 'online_payment_attempted',
#        'utm_campaign', 'utm_reff', 'utm_source', 'is_fast_checkout',
#        'order_place', 'recommended_discount_id', 'temp_discount', 'referrer',
#        'discount_reason', 'additional_off', 'additional_off_expiry',
#        'additional_off_type', 'eligible_nat_cash', 'eligible_nat_cash_expiry',
#        'redeemed_nat_cash', 'utm_medium', 'discount_amount', 'discount_type',
# ...

# %%
df[['cart_state']].value_counts()
# Out:
# cart_state
# orderPlaced    1563732
# Created        1045462
# Name: count, dtype: int64

# %%
for col in df.columns:
    print(f"Value counts for {col}:")
    print(df[col].value_counts())  # Show top 10 most common values
    print("\n" + "="*50 + "\n")
# Out:
# Value counts for id:
# id
# 866910     1
# 2606381    1
# 2606374    1
# 2606375    1
# 2606376    1
#           ..
# 1736648    1
# 1736649    1
# 1736650    1
# 1736651    1
# 3476141    1
# Name: count, Length: 2609194, dtype: int64
#
# ...
#
# Value counts for discount_code:
# discount_code
# NEWHABIT50              411544
# FREESPA                 372710
# FRESH35                 328889
# FREEHANDMALAI           209218
# FREECOMBO               181427
#                          ...
# PARAFIRST10                  1
# GPAY50-GI2TINJYHE4A          1
# PAYTM50-GIYDCNJRGMZQ         1
# GIZTQNRSGEZA                 1
# PAYTM50-GM2TOOJWGEYA         1
# Name: count, Length: 45256, dtype: int64
#
# ...
#
# Value counts for applied_count:
# applied_count
# 2       661567
# 1       471552
# 3       427659
# 4       312698
# 5       172158
#          ...
# 1773         1
# 452          1
# 371          1
# 398          1
# 328          1
# Name: count, Length: 419, dtype: int64
#
# ...
#
# ...
